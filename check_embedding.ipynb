# %%
data = {}
with open('./analysis/vocab') as f:
    for line in f:
        line = line.split()
        data[line[0]] = int(line[1])

# %%
mapping = []

# %%
with open('./embedding/wiki-news-300d-1M.vec') as f:
    for i,line in enumerate(f):
        line = line.split()
        mapping.append(line[0])

# %%
import json
with open('inverted.json') as f:
    for line in f:
        pass
invert = json.loads(line)

# %%
ins,out=0,0
temp = []
for key in data:
    if(key in mapping):
        ins += data[key]
    else:
        ins += data[key]
        temp.append((key,data[key]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5c0ce1b0335a> in <module>
#       2 temp = []
#       3 for key in data:
# ----> 4     if(key in mapping):
#       5         ins += data[key]
#       6     else:
#
# KeyboardInterrupt:

# %%
def partition(invert,large,smalls):
    for key,n in invert[large]['docs'].items():
        for small in smalls:
            try:
                invert[small]['docs'][key]+=n
            except:
                invert[small]['docs'][key]=n

    del invert[large]

# %%
partition(invert,'it’s',['it','is'])

# %%
partition(invert,'“i',['“','i'])

# %%
partition(invert,'don’t',['do','not'])

# %%
w[1:-1]
# Out:
# '02'

# %%
c = []
for key in invert:
    if('’' == key[0]):
        c.append(key)
ex = []
for w in c:
    try:
        if(w[-1]=='’' and len(w[1:-1])>0):
            partition(invert,w,[w[0],w[1:-1],w[-1]])
        elif(len(w[1:])>0):
            partition(invert,w,[w[0],w[1:]])
    except:
        ex.append(w)

# %%
ex
# Out:
# ['’70swomen',
#  '’fros',
#  '’ilima',
#  '’wichcraft”',
#  '’mongst',
#  '’tain’t',
#  '’it’s',
#  '’dray’s',
#  '’tawns',
#  '’rugula',
#  '’llall',
#  '’hoansi',
#  '’cuenoscenti',
#  '’cadas',
#  '’wiches',
#  '’pataphysics',
#  '’roids',
#  '’zo’s',
#  '’rithmatic',
#  '’bronspeak',
#  '’causeit’s',
#  '’chups\xad',
#  '’raqeri',
#  '’dilfers',
#  '’pittin’',
#  '’”absher',
#  '’twere',
#  '’trane”',
#  '’79”',
#  '’murican',
#  '’emround',
#  '’tisn’t',
#  '’jects',
#  '’\xad\xad\xad\xad\xad\xad\xad\xad',
#  '’dcsakjhg',
#  '’04s',
#  '’buked',
#  '’ousemaid',
#  '’68’s',
#  '’stached',
#  '’’c”',
#  '’twould',
#  '’’melichar',
#  '’tatuh',
#  '’ritin’',
#  '’unbecause',
#  '’ngrato',
#  '’sokay',
#  '’…fortunately',
#  '’”calishain',
#  '’…before',
#  '’salright',
#  '’…omissions',
#  '’phoid',
#  '’30s–“up',
#  '’”metamorphoses”',
#  '’007′',
#  '’80s…',
#  '’…kirk',
#  '’1989′',
#  '’…salvation',
#  '’60s—but',
#  '’okhai',
#  '’”…really',
#  '’50‑50′',
#  '’em…',
#  '’’”',
# ...

# %%
c = []
for key in invert:
    if('’' == key[0]):
        c.append(key)
c
# Out:
# ['’06',
#  '’07',
#  '’',
#  '’em',
#  '’s',
#  '’”',
#  '’’',
#  '’90s',
#  '’09',
#  '’11',
#  '’98',
#  '’70s',
#  '’80s',
#  '’50s',
#  '’60s',
#  '’40s',
#  '’n’',
#  '’14',
#  '’08',
#  '’round',
#  '’20s',
#  '’30s',
#  '’92',
#  '’00s',
#  '’cause',
#  '’60s”',
#  '’68',
#  '’94',
#  '’n',
#  '’em”',
#  '’81',
#  '’99',
#  '’90',
#  '’12',
#  '’52',
#  '’60',
#  '’rents',
#  '’67',
#  '’04',
#  '’79',
#  '’bout',
#  '’sup',
#  '’01',
#  '’02',
#  '’00',
#  '’13',
#  '’am',
#  '’65',
#  '’59',
#  '’64',
#  '’56',
#  '’78',
#  '’89',
#  '’96',
#  '’cue',
#  '’91',
#  '’72',
#  '’twas',
#  '’88',
#  '’…',
#  '’76',
#  '’fro',
#  '’hood',
#  '’the',
#  '’05',
#  '’58',
#  '’66”',
#  '’book',
#  '’melo',
#  '’cross',
#  '’s”',
#  '’s’',
#  '’90s”',
#  '’86',
#  '’15',
#  '’tis',
#  '’tit',
#  '’84',
#  '’hoods',
#  '’69',
#  '’er',
#  '’way',
#  '’course',
#  '’93',
#  '’73',
#  '’85',
#  '’02’',
#  '’57',
#  '’10',
#  '’dray”',
#  '’82',
#  '’canes',
#  '’do',
#  '’97',
# ...

# %%
temp[:40]
# Out:
# [('it’s', 516104),
#  ('“i', 325595),
#  ('don’t', 316237),
#  ('“the', 294077),
#  ('that’s', 228057),
#  ('didn’t', 183080),
#  ('he’s', 168969),
#  ('“we', 164853),
#  ('i’m', 163063),
#  ('doesn’t', 129577),
#  ('there’s', 124298),
#  ('trump’s', 121560),
#  ('can’t', 117663),
#  ('we’re', 112152),
#  ('you’re', 106213),
#  ('“it’s', 99038),
#  ('they’re', 98922),
#  ('“it', 97892),
#  ('isn’t', 88420),
#  ('wasn’t', 79713),
#  ('“a', 72677),
#  ('i’ve', 68455),
#  ('“this', 67188),
#  ('won’t', 64248),
#  ('“you', 59522),
#  ('“he', 57534),
#  ('“if', 56241),
#  ('we’ve', 54052),
#  ('obama’s', 51945),
#  ('what’s', 51420),
#  ('“i’m', 48874),
#  ('“but', 47602),
#  ('loudoun', 44329),
#  ('“they', 44164),
#  ('here’s', 44000),
#  ('couldn’t', 43887),
#  ('aren’t', 42390),
#  ('she’s', 42376),
#  ('“and', 42299),
#  ('wouldn’t', 40476)]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
